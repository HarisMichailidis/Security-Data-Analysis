# %%
infile = '/home/haris/dev/projects/Security-Data-Analysis/connection_logs/conn_1000000.log'
import pandas as pd
columns = ['ts','uid','id_orig_h','id_orig_p','id_resp_h','id_resp_p','proto','service','duration','orig_bytes','resp_bytes','conn_state','local_orig','missed_bytes','history','orig_pkts','orig_ip_bytes','resp_pkts','resp_ip_bytes','tunnel_parents','threat','sample']
conn_df = pd.read_csv(infile, sep="\t", header=None, names=columns)

# %%
from datetime import datetime
conn_df['ts'] = [str(datetime.fromtimestamp(float(date+i))).split('.')[0] for i,date in enumerate(conn_df['ts'].values,0)]

# %%
conn_df.head(1000)
# Out:
#                       ts                 uid        id_orig_h  id_orig_p  \
# 0    2012-03-16 14:30:00  CCUIP21wTjqkj8ZqX5   192.168.202.79      50463
# 1    2012-03-16 14:30:01  Csssjd3tX0yOTPDpng   192.168.202.79      46117
# 2    2012-03-16 14:30:02  CHEt7z3AzG4gyCNgci   192.168.202.79      50465
# 3    2012-03-16 14:30:03  CKnDAp2ohlvN6rpiXl   192.168.202.79      50467
# 4    2012-03-16 14:30:04    CGUBcoXKxBE8gTNl   192.168.202.79      46119
# 5    2012-03-16 14:30:05  CRksHc2i8qahpGOP19   192.168.202.79      46121
# 6    2012-03-16 14:30:06  C56nlH3SloWOj44ABi   192.168.202.79      46123
# 7    2012-03-16 14:30:07  CNTrjn42F3LB58MZH6   192.168.202.79      50469
# 8    2012-03-16 14:30:08  C1D7mK1PlzKEnEyG03   192.168.202.79      50471
# 9    2012-03-16 14:30:09   CGF1bVMyl9ALKI32l   192.168.202.79      50473
# 10   2012-03-16 14:30:10  CC6D613v9i3xbmQbAf   192.168.202.79      46125
# 11   2012-03-16 14:30:11  C5hpJ62EKjvbtDNVr8   192.168.202.79      46127
# ...

# %%
conn_df.head(1000)
# Out:
#                       ts                 uid        id_orig_h  id_orig_p  \
# 0    2012-03-16 14:30:00  CCUIP21wTjqkj8ZqX5   192.168.202.79      50463
# 1    2012-03-16 14:30:00  Csssjd3tX0yOTPDpng   192.168.202.79      46117
# 2    2012-03-16 14:30:00  CHEt7z3AzG4gyCNgci   192.168.202.79      50465
# 3    2012-03-16 14:30:00  CKnDAp2ohlvN6rpiXl   192.168.202.79      50467
# 4    2012-03-16 14:30:00    CGUBcoXKxBE8gTNl   192.168.202.79      46119
# 5    2012-03-16 14:30:00  CRksHc2i8qahpGOP19   192.168.202.79      46121
# 6    2012-03-16 14:30:00  C56nlH3SloWOj44ABi   192.168.202.79      46123
# 7    2012-03-16 14:30:00  CNTrjn42F3LB58MZH6   192.168.202.79      50469
# 8    2012-03-16 14:30:00  C1D7mK1PlzKEnEyG03   192.168.202.79      50471
# 9    2012-03-16 14:30:00   CGF1bVMyl9ALKI32l   192.168.202.79      50473
# 10   2012-03-16 14:30:00  CC6D613v9i3xbmQbAf   192.168.202.79      46125
# 11   2012-03-16 14:30:00  C5hpJ62EKjvbtDNVr8   192.168.202.79      46127
# ...

# %%
# S_id_orig_h = pd.Series(conn_df.id_orig_h)
# print S_id_orig_h.value_counts()
# S_id_resp_h = pd.Series(conn_df.id_resp_h)
# print S_id_resp_h.value_counts()

# %%
conn_df.groupby(["id_orig_h"]).sum().sort_values(by='orig_ip_bytes',ascending=False)
# Out:
#                                         id_orig_p    id_resp_p  missed_bytes  \
# id_orig_h
# 192.168.202.79                        34143638675  17316059911             0
# 192.168.202.83                        19199575402   3522163557             0
# 192.168.202.101                        1058435494    181869816             0
# 192.168.202.76                          141631446     47100264             0
# 192.168.202.96                          628484400    112387515             0
# 192.168.203.62                           38320665        49485             0
# 192.168.203.61                           27338075      3568421             0
# 192.168.202.73                          144764823      1369579             0
# 192.168.202.81                           91422260     43377017             0
# 192.168.204.70                            7846226      3618616             0
# 192.168.202.91                            1502124        14208             0
# ...

# %%
conn_df.groupby(["id_resp_h"]).sum().sort_values(by='resp_ip_bytes',ascending=False)
# Out:
#                    id_orig_p   id_resp_p  missed_bytes  orig_pkts  \
# id_resp_h
# 192.168.22.254       2323749       19633             0       8981
# 192.168.206.44   19180664905  3522142145             0     412293
# 192.168.229.153   4413306244  2279028133             0     134238
# 192.168.202.78      20088798     3456264             0       5972
# 192.168.229.251   4355698998  2159803712             0      83014
# 192.168.229.101   4294238601  2156694357             0      74440
# 192.168.229.156   4288404214  2157126162             0      75054
# 192.168.229.252   4252873584  2162824464             0      72275
# 192.168.229.254   8533746693  4313224373             0     152977
# 192.168.229.1     4220006689  2156149403             0      66572
# 192.168.205.253      1502124       14208             0        814
# 192.168.207.4      164252454      182373             0       3524
# 192.168.202.68       2429436     3610945             0       1834
# ...

# %%
orig_l = ['192.168.202.79','192.168.202.83','192.168.202.101','192.168.202.76']

# %%
new_df = conn_df[conn_df['id_orig_h'].isin(orig_l)].sort_values('ts')

# %%
new_df.head(100)
# Out:
#                       ts                 uid       id_orig_h  id_orig_p  \
# 0    2012-03-16 14:30:00  CCUIP21wTjqkj8ZqX5  192.168.202.79      50463
# 104  2012-03-16 14:30:00  Cm0c5y1R3iuZpU2KZ5  192.168.202.79      50563
# 105  2012-03-16 14:30:00   C2pPky3IhsHmcBHOo  192.168.202.79      46217
# 106  2012-03-16 14:30:00  CY8mxm4Doz5qnKaCTl  192.168.202.79      50565
# 107  2012-03-16 14:30:00  C4r0cd2k7thQKn1O5e  192.168.202.79      46219
# 108  2012-03-16 14:30:00  Cx0vWj3dJk0672Ovgh  192.168.202.79      46221
# 109  2012-03-16 14:30:00   CDm5OE4ZC1gKP70m4  192.168.202.79      50567
# 110  2012-03-16 14:30:00  CwSMqr1HAGOH4fUCc8  192.168.202.79      50569
# 103  2012-03-16 14:30:00  CzBBt31G4JE5F44Dv3  192.168.202.79      50561
# 111  2012-03-16 14:30:00  CREiUN2g5sE2ZHoZHb  192.168.202.79      50571
# 113  2012-03-16 14:30:00   CVbBRh3oJv2QqRgW9  192.168.202.79      46225
# 114  2012-03-16 14:30:00   CNExcKCdjdtlBSzY4  192.168.202.79      46227
# ...

# %%
new_df.sort_values(by='resp_ip_bytes',ascending=False)
